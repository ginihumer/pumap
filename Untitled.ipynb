# %%
import test_parametric_umap

# %%
emb, y = test_parametric_umap.test_create_model()
# Out:
# D:\CG\projective latent interventions\pumap\umap\parametric_umap.py:270: UserWarning: Data should be scaled to the range 0-1 for cross-entropy reconstruction loss.
#   warn(
# Epoch 1/10
# 34/34 [==============================] - 0s 3ms/step - loss: 1.4282
# Epoch 2/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6307
# Epoch 3/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.5716
# Epoch 4/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.5484
# Epoch 5/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.5221
# Epoch 6/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.5209
# Epoch 7/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.5083
# Epoch 8/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.4923
# Epoch 9/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.4652
# Epoch 10/10
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(emb[:,0], emb[:,1], c=y)

# %%
from sklearn.datasets import make_moons
import numpy as np
import tensorflow as tf
from umap.parametric_umap import ParametricUMAP, load_ParametricUMAP

# %%
X, y = make_moons(100)
embedder = ParametricUMAP(optimizer=tf.keras.optimizers.Adam(),
        batch_size=None,
        dims=None,
        encoder=None,
        loss_report_frequency=10,
        n_training_epochs=1)
embedding = embedder.fit_transform(X)
# Out:
# D:\CG\projective latent interventions\pumap\umap\parametric_umap.py:270: UserWarning: Data should be scaled to the range 0-1 for cross-entropy reconstruction loss.
#   warn(
# Epoch 1/10
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2455
# Epoch 2/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6027
# Epoch 3/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.5687
# Epoch 4/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.5479
# Epoch 5/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.5106
# Epoch 6/10
# 34/34 [==============================] - 0s 4ms/step - loss: 0.5138
# Epoch 7/10
# 34/34 [==============================] - 0s 4ms/step - loss: 0.5089
# Epoch 8/10
# 34/34 [==============================] - 0s 4ms/step - loss: 0.4891
# Epoch 9/10
# 34/34 [==============================] - 0s 3ms/step - loss: 0.4690
# Epoch 10/10
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(embedding[:,0], embedding[:,1], c=y)
